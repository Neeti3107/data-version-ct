# %% [markdown]
# # Creating a Web App
#
# **Author:** Manaranjan Pradhan</br>
# **Email ID:** manaranjan@gmail.com</br>
# **LinkedIn:** https://www.linkedin.com/in/manaranjanpradhan/
#
# Use [Streamlit](https://streamlit.io/)
#
# Streamlit turns data scripts into shareable web apps in minutes.
# All in pure Python. No front‑end experience required.

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.31.1-py2.py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 9.9 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting validators<1,>=0.2
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (4.4.0)
# Collecting rich<14,>=10.14.0
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (1.23.5)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (2.0.3)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 268.7 kB/s eta 0:00:0031m11.6 MB/s eta 0:00:01
# Collecting altair<6,>=4.0
#   Using cached altair-5.2.0-py3-none-any.whl (996 kB)
# Requirement already satisfied: pyarrow>=7.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (12.0.1)
# Requirement already satisfied: requests<3,>=2.27 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (5.3.1)
# Collecting pydeck<1,>=0.8.0b4
#   Using cached pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (6.1)
# Collecting blinker<2,>=1.0.0
#   Using cached blinker-1.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (6.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (4.23.4)
# Collecting tzlocal<6,>=1.1
#   Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from streamlit) (22.0)
# Requirement already satisfied: jinja2 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: toolz in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2022.12.7)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 72.2 kB/s eta 0:00:0031m12.7 MB/s eta 0:00:01
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: validators, tzlocal, smmap, mdurl, blinker, pydeck, markdown-it-py, gitdb, rich, gitpython, altair, streamlit
# Successfully installed altair-5.2.0 blinker-1.7.0 gitdb-4.0.11 gitpython-3.1.42 markdown-it-py-3.0.0 mdurl-0.1.2 pydeck-0.8.1b0 rich-13.7.1 smmap-5.0.1 streamlit-1.31.1 tzlocal-5.2 validators-0.22.0

# %% [markdown]
# ## Creating the App

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
from joblib import load

carmodel = load('carsmodel.pkl')

def predict_price(model, 
                  fuelType,
                  transmission, 
                  ownerType,
                  kmDriven, 
                  age):

    inputs_dict = {'KM_Driven' : float(kmDriven), 
                   'Fuel_Type': fuelType, 
                   'Age': float(age), 
                   'Transmission': transmission, 
                   'Owner_Type': ownerType, 
                   'Model': model.lower()}

    df = pd.DataFrame(inputs_dict, index = [0])


    price = carmodel.predict(df)[0]
    return price 

 
#function to define the app_layout
def app_layout():
    
    st.title('Car Resale Value Prediction')
    st.header('Enter car detail:')  
    
    ## Creating the user input fields 

    model = st.selectbox('Model:', 
                         ['ertiga', 'swift', 'alto', 'wagon', 
                          'vitara', 'zen', 'ritz',
                          'omni', 'eeco', 'ciaz', 'baleno', 
                          'a-star', 'celerio', 'dzire'])

    transmission = st.radio('Transmission:', 
                            ['Manual', 'Automatic'], 
                            horizontal=True)
    
    fueltype = st.radio('Fuel Type:', 
                        ['Petrol', 'Diesel'], 
                        horizontal=True)
    
    ownertype = st.radio('Owner Type:', 
                         ['First', 'Second', 'Third'], 
                         horizontal=True)
    
    age = st.number_input('Age:', 
                          min_value=1,
                          max_value=10, 
                          value=1)
    
    kmdriven = st.number_input('KM Driven in 1000 kms.:', 
                               min_value=1.0, 
                               max_value=150.0, 
                               value=10.0)
    
    if st.button('Predict Price'):
        price = predict_price(model, 
                              fueltype, 
                              transmission, 
                              ownertype, 
                              kmdriven, 
                              age)
        st.success(f'Explected resale value of the car is : INR {np.round(price, 2)} Lakhs')
 
if __name__=='__main__':
  app_layout()
# Out:
# Overwriting app.py

# %% [markdown]
# ## Run the UI

# %%
# !streamlit run app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.200:8501
#
# /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/base.py:348: InconsistentVersionWarning: Trying to unpickle estimator OneHotEncoder from version 1.2.1 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/base.py:348: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.2.1 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/base.py:348: InconsistentVersionWarning: Trying to unpickle estimator FunctionTransformer from version 1.2.1 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/base.py:348: InconsistentVersionWarning: Trying to unpickle estimator ColumnTransformer from version 1.2.1 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/base.py:348: InconsistentVersionWarning: Trying to unpickle estimator LinearRegression from version 1.2.1 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2024-03-05 12:51:40.777 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 535, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/manaranjanp/Documents/Work/ML Mentorship/Class/Session_11/app.py", line 75, in <module>
#     app_layout()
#   File "/Users/manaranjanp/Documents/Work/ML Mentorship/Class/Session_11/app.py", line 66, in app_layout
#     price = predict_price(model,
#   File "/Users/manaranjanp/Documents/Work/ML Mentorship/Class/Session_11/app.py", line 25, in predict_price
#     price = carmodel.predict(df)[0]
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/pipeline.py", line 514, in predict
#     Xt = transform.transform(Xt)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/utils/_set_output.py", line 157, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py", line 827, in transform
#     Xs = self._fit_transform(
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py", line 681, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/joblib/parallel.py", line 1051, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/joblib/parallel.py", line 864, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/joblib/parallel.py", line 263, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/pipeline.py", line 940, in _transform_one
#     res = transformer.transform(X)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/pipeline.py", line 696, in transform
#     Xt = transform.transform(Xt)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/utils/_set_output.py", line 157, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/Users/manaranjanp/anaconda3/envs/mylabs/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py", line 1036, in transform
#     if self._drop_idx_after_grouping is not None:
# AttributeError: 'OneHotEncoder' object has no attribute '_drop_idx_after_grouping'
